# %% [markdown]
# # EDA

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/Python Data Mastery/EstructuraDirectorio/03_MACHINE_LEARNING/08_CASOS/003_RIESGOS'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_cat = 'cat_resultado_calidad.pickle'
nombre_num = 'num_resultado_calidad.pickle'

# %% [markdown]
# Cargar los datos.

# %%
cat = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_cat)
num = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_num)

# %% [markdown]
# ## EDA CATEGÓRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
cat.columns
# Out:
# Index(['empleo', 'antiguedad_empleo', 'ingresos_verificados', 'rating',
#        'vivienda', 'descripcion', 'finalidad', 'num_cuotas', 'estado',
#        'cat_tarjetas_75p'],
#       dtype='object')

# %%
variables = ['antiguedad_empleo', 'ingresos_verificados', 'rating', 'vivienda',
       'finalidad', 'num_cuotas', 'estado','cat_tarjetas_75p']

# %%
def frecuencias_cat(df_cat):
    resultado = df_cat[variables].apply(lambda x: x.value_counts(normalize = True)).T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return(resultado)

# %%
frecuencias_cat(cat)
# Out:
#                 Variable                                              Valor  \
# 9      antiguedad_empleo                                            9 years
# 8      antiguedad_empleo                                            8 years
# 7      antiguedad_empleo                                            7 years
# 6      antiguedad_empleo                                            6 years
# 4      antiguedad_empleo                                            4 years
# 5      antiguedad_empleo                                            5 years
# 11     antiguedad_empleo                                        desconocido
# 0      antiguedad_empleo                                             1 year
# 3      antiguedad_empleo                                            3 years
# 10     antiguedad_empleo                                           < 1 year
# 2      antiguedad_empleo                                            2 years
# 1      antiguedad_empleo                                          10+ years
# 55      cat_tarjetas_75p                                               >75%
# 54      cat_tarjetas_75p                                               <10%
# 53      cat_tarjetas_75p                                             11-75%
# 46                estado                                            Default
# 47                estado  Does not meet the credit policy. Status:Charge...
# 48                estado  Does not meet the credit policy. Status:Fully ...
# 51                estado                                  Late (16-30 days)
# 50                estado                                    In Grace Period
# 52                estado                                 Late (31-120 days)
# 44                estado                                        Charged Off
# 45                estado                                            Current
# 49                estado                                         Fully Paid
# 31             finalidad                                        educational
# 38             finalidad                                   renewable_energy
# 41             finalidad                                            wedding
# 33             finalidad                                              house
# 40             finalidad                                           vacation
# 36             finalidad                                             moving
# 28             finalidad                                                car
# 39             finalidad                                     small_business
# 35             finalidad                                            medical
# 34             finalidad                                     major_purchase
# 37             finalidad                                              other
# 32             finalidad                                   home_improvement
# 29             finalidad                                        credit_card
# 30             finalidad                                 debt_consolidation
# 14  ingresos_verificados                                           Verified
# 12  ingresos_verificados                                       Not Verified
# 13  ingresos_verificados                                    Source Verified
# 43            num_cuotas                                          60 months
# 42            num_cuotas                                          36 months
# 21                rating                                                  G
# 20                rating                                                  F
# 19                rating                                                  E
# 18                rating                                                  D
# 15                rating                                                  A
# 17                rating                                                  C
# 16                rating                                                  B
# 24              vivienda                                               NONE
# 25              vivienda                                              OTHER
# 22              vivienda                                                ANY
# 26              vivienda                                                OWN
# 27              vivienda                                               RENT
# 23              vivienda                                           MORTGAGE
#
#     Frecuencia
# 9     0.035755
# 8     0.040767
# 7     0.040947
# 6     0.045507
# 4     0.060709
# 5     0.062183
# 11    0.064736
# 0     0.065254
# 3     0.081139
# 10    0.084073
# 2     0.090315
# 1     0.328613
# 55    0.240081
# 54    0.274779
# 53    0.485139
# 46    0.000022
# 47    0.000374
# 48    0.000877
# 51    0.001891
# 50    0.003883
# 52    0.009500
# 44    0.118153
# 45    0.388927
# 49    0.476373
# 31    0.000194
# 38    0.000597
# 41    0.001000
# 33    0.006379
# 40    0.007119
# 36    0.007270
# 28    0.010391
# 39    0.011290
# 35    0.011830
# 34    0.022401
# 37    0.063017
# 32    0.065290
# 29    0.225030
# 30    0.568191
# 14    0.277757
# 12    0.330879
# 13    0.391365
# 43    0.286724
# 42    0.713276
# 21    0.005544
# 20    0.018654
# 19    0.060364
# 18    0.143668
# 15    0.191339
# 17    0.288270
# 16    0.292161
# 24    0.000022
# 25    0.000072
# 22    0.000424
# 26    0.111400
# 27    0.398204
# 23    0.489878

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat[variables])

# %% [markdown]
# Conclusiones:
#
# En transformación:
#
# * En vivienda juntar ANY, NONE y OTHER a la categoria mayoritaria
# * En finalidad juntar renewable_energy, educational y wedding en 'otros'
# * Crear la target a partir de estado

# %% [markdown]
# ## EDA NUMÉRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
num
# Out:
#             ingresos    dti  num_hipotecas  num_lineas_credito  \
# id_cliente
# 4798121      65000.0  25.40            1.0                15.0
# 46641215    135000.0  14.68            0.0                19.0
# 87998444    188000.0  11.69            3.0                15.0
# 132883631   125000.0   9.00            1.0                 6.0
# 77861711     50000.0  29.31            1.0                 8.0
# ...              ...    ...            ...                 ...
# 73222117     85000.0  33.05            1.0                25.0
# 119242742    20000.0   8.02            0.0                 5.0
# 51876926     42000.0  20.85            6.0                 9.0
# 135641397   285000.0   6.02            3.0                 9.0
# 53664762    168000.0   4.69            0.0                 8.0
#
#             porc_tarjetas_75p  porc_uso_revolving  num_cancelaciones_12meses  \
# id_cliente
# 4798121                  85.7                86.2                        0.0
# 46641215                  0.0                16.3                        0.0
# 87998444                  0.0                 3.3                        0.0
# 132883631                33.3                69.9                        0.0
# 77861711                  0.0                40.8                        0.0
# ...                       ...                 ...                        ...
# 73222117                 90.0                76.0                        1.0
# 119242742                66.7                33.2                        0.0
# 51876926                100.0                81.6                        0.0
# 135641397                25.0                21.1                        0.0
# 53664762                  0.0                52.4                        0.0
#
#             num_derogatorios  principal  tipo_interes  imp_cuota  \
# id_cliente
# 4798121                  0.0    10000.0         17.77     360.38
# 46641215                 0.0    24000.0          6.39     734.38
# 87998444                 0.0    27000.0          8.99     560.35
# 132883631                0.0    22000.0         10.90     719.22
# 77861711                 0.0    14400.0         15.31     501.37
# ...                      ...        ...           ...        ...
# 73222117                 0.0     3000.0          9.75      96.45
# 119242742                0.0     2500.0         12.62      83.78
# 51876926                 0.0     8000.0         12.29     266.83
# 135641397                0.0    30000.0         17.47    1076.62
# 53664762                 2.0    30050.0         18.25     767.17
#
#             imp_amortizado  imp_recuperado  num_meses_desde_ult_retraso
# id_cliente
# 4798121            6362.96            0.00                          0.0
# 46641215          24000.00            0.00                        999.0
# 87998444          12443.00            0.00                        999.0
# 132883631         22000.00            0.00                         16.0
# 77861711           2310.49         6430.36                          8.0
# ...                    ...             ...                          ...
# 73222117           3000.00            0.00                        999.0
# 119242742           996.06            0.00                        999.0
# 51876926           8000.00            0.00                         13.0
# 135641397          5387.53            0.00                         25.0
# 53664762           2964.44         2750.88                          0.0
#
# [139057 rows x 14 columns]

# %%
estadisticos_cont(num)
# Out:
#                                 count          mean    median           std  \
# ingresos                     139057.0  75102.629385  65000.00  42357.525906
# dti                          139057.0     18.698723     17.85      9.694864
# num_hipotecas                139057.0      1.507785      1.00      1.876290
# num_lineas_credito           139057.0     11.601617     11.00      5.636675
# porc_tarjetas_75p            139057.0     41.072182     33.30     36.464240
# porc_uso_revolving           139057.0     50.311199     50.30     24.699113
# num_cancelaciones_12meses    139057.0      0.008349      0.00      0.101738
# num_derogatorios             139057.0      0.197408      0.00      0.567729
# principal                    139057.0  14977.240988  12800.00   9130.903653
# tipo_interes                 139057.0     13.106488     12.62      4.833698
# imp_cuota                    139057.0    444.337774    377.33    265.891742
# imp_amortizado               139057.0   9469.891076   7000.00   8270.228854
# imp_recuperado               139057.0    143.976477      0.00    756.576694
# num_meses_desde_ult_retraso  139057.0    472.131565     69.00    482.521229
#
#                                 min       25%       50%       75%        max
# ingresos                       0.00  46000.00  65000.00  92000.00  300000.00
# dti                            0.00     11.97     17.85     24.50     100.00
# num_hipotecas                  0.00      0.00      1.00      2.00      32.00
# num_lineas_credito             0.00      8.00     11.00     14.00      91.00
# porc_tarjetas_75p              0.00      0.00     33.30     66.70     100.00
# porc_uso_revolving             0.00     31.60     50.30     69.30     100.00
# num_cancelaciones_12meses      0.00      0.00      0.00      0.00       7.00
# num_derogatorios               0.00      0.00      0.00      0.00      46.00
# principal                    500.00   8000.00  12800.00  20000.00   40000.00
# tipo_interes                   5.31      9.49     12.62     15.99      30.99
# imp_cuota                      7.61    251.06    377.33    589.56    1714.54
# imp_amortizado                 0.00   3000.00   7000.00  13750.00   40000.00
# imp_recuperado                 0.00      0.00      0.00      0.00   33407.16
# num_meses_desde_ult_retraso    0.00     25.00     69.00    999.00     999.00

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_continuas(num)

# %% [markdown]
# Vamos a analizar el detalle de imp_amortizado e imp_recuperado, ya que son relevantes para la target del modelo LGD.

# %%
ratios = num[['principal','imp_amortizado','imp_recuperado']].copy()

# %%
ratios['r_amortizado_principal'] = ratios.imp_amortizado / ratios.principal
ratios['r_recuperado_principal'] = ratios.imp_recuperado / ratios.principal

# %%
ratios.describe().T
# Out:
#                            count          mean          std    min  \
# principal               139057.0  14977.240988  9130.903653  500.0
# imp_amortizado          139057.0   9469.891076  8270.228854    0.0
# imp_recuperado          139057.0    143.976477   756.576694    0.0
# r_amortizado_principal  139057.0      0.662341     0.369411    0.0
# r_recuperado_principal  139057.0      0.008995     0.041575    0.0
#
#                                 25%           50%      75%           max
# principal               8000.000000  12800.000000  20000.0  40000.000000
# imp_amortizado          3000.000000   7000.000000  13750.0  40000.000000
# imp_recuperado             0.000000      0.000000      0.0  33407.160000
# r_amortizado_principal     0.273879      0.871219      1.0      1.000012
# r_recuperado_principal     0.000000      0.000000      0.0      1.220774

# %% [markdown]
# Conclusiones:
#
# * En transformación convertir num_derogatorios a binaria
# * Revisar en profundidad la relación entre estado e imp_recuperado

# %%
temp = cat[['estado']].merge(num[['imp_recuperado']], left_index=True, right_index=True)
temp.groupby('estado').imp_recuperado.mean()
# Out:
# estado
# Charged Off                                            1216.423613
# Current                                                   0.000000
# Default                                                   0.000000
# Does not meet the credit policy. Status:Charged Off     674.942115
# Does not meet the credit policy. Status:Fully Paid        0.000000
# Fully Paid                                                0.000000
# In Grace Period                                           0.000000
# Late (16-30 days)                                         0.000000
# Late (31-120 days)                                        0.000000
# Name: imp_recuperado, dtype: float64

# %% [markdown]
# Efectivamente sólo hay importe recuperado en el estado Charged Off.

# %% [markdown]
# ## GUARDAR DATASETS TRAS EDA

# %% [markdown]
# Guarda los avances en cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.
#
# *NOTA: En algunos casos no hay cambios en los ficheros en esta fase, así que este paso es opcional.Pero si no guardas estos ficheros acuérdate de modificar la importación en el siguiente notebook.*

# %%
#Definir los nombres de los archivos
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_eda.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_eda.pickle'

# %%
#Guardar los archivos
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
